# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, f1_score, make_scorer
import optuna
from optuna.samplers import TPESampler

import warnings
warnings.filterwarnings('ignore')

# %%
df_up = pd.read_csv('/kaggle/input/credit-score-data/clean data/train_transformed_upsampled.csv')
df_test = pd.read_csv('/kaggle/input/credit-score-data/clean data/test_transformed.csv')

print(f"Upsampled training: {df_up.shape}")
print(f"Test: {df_test.shape}")
# Out:
# Upsampled training: (127725, 35)
# Test: (20000, 35)

# %%
def prepare_data(df):
    X = df.drop('Credit_Score', axis=1)
    y = df['Credit_Score']
    return X, y

X_train, y_train = prepare_data(df_up)
X_test, y_test = prepare_data(df_test)

# %% [markdown]
# # Baseline

# %%
rf_baseline = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf_baseline.fit(X_train, y_train)

y_train_pred_baseline = rf_baseline.predict(X_train)
y_test_pred_baseline = rf_baseline.predict(X_test)

baseline_train_f1 = f1_score(y_train, y_train_pred_baseline, average='macro')
baseline_test_f1 = f1_score(y_test, y_test_pred_baseline, average='macro')
baseline_train_acc = accuracy_score(y_train, y_train_pred_baseline)
baseline_test_acc = accuracy_score(y_test, y_test_pred_baseline)

print(f"Baseline Train F1-macro: {baseline_train_f1:.4f}, Train Accuracy: {baseline_train_acc:.4f}")
print(f"Baseline Test F1-macro: {baseline_test_f1:.4f}, Test Accuracy: {baseline_test_acc:.4f}")
# Out:
# Baseline Train F1-macro: 1.0000, Train Accuracy: 1.0000
# Baseline Test F1-macro: 0.8153, Test Accuracy: 0.8206

# %% [markdown]
# # Fine-Tuning

# %% [markdown]
# ## 1) Grid-Search

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [4, 6, 8],
    'max_features': ['sqrt', 'log2', None]
}

# %%
f1_scorer = make_scorer(f1_score, average='macro')

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42, n_jobs=-1),
    param_grid,
    cv=3,
    scoring=f1_scorer,
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [4, 6, 8],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 200, 300]},
#              scoring=make_scorer(f1_score, average=macro), verbose=1)

# %%
print(f"\nBest GridSearch F1-macro (CV): {grid_search.best_score_:.4f}")
print(f"Best GridSearch parameters:")
for param, value in grid_search.best_params_.items():
    print(f"  {param}: {value}")

rf_grid = grid_search.best_estimator_
y_train_pred_grid = rf_grid.predict(X_train)
y_test_pred_grid = rf_grid.predict(X_test)
# Out:
# Best GridSearch F1-macro (CV): 0.7507
# Best GridSearch parameters:
#   max_depth: 8
#   max_features: None
#   n_estimators: 300

# %%
grid_train_f1 = f1_score(y_train, y_train_pred_grid, average='macro')
grid_test_f1 = f1_score(y_test, y_test_pred_grid, average='macro')
grid_train_acc = accuracy_score(y_train, y_train_pred_grid)
grid_test_acc = accuracy_score(y_test, y_test_pred_grid)

print(f"\nGridSearch Train F1-macro: {grid_train_f1:.4f}, Train Accuracy: {grid_train_acc:.4f}")
print(f"GridSearch Test F1-macro: {grid_test_f1:.4f}, Test Accuracy: {grid_test_acc:.4f}")

print("\nGridSearch Train Classification Report:")
print(classification_report(y_train, y_train_pred_grid, digits=4))

print("GridSearch Test Classification Report:")
print(classification_report(y_test, y_test_pred_grid, digits=4))
# Out:
# GridSearch Train F1-macro: 0.7575, Train Accuracy: 0.7628
# GridSearch Test F1-macro: 0.6884, Test Accuracy: 0.6926
#
# GridSearch Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7612    0.8284    0.7934     42575
#            1     0.7755    0.5898    0.6700     42575
#            2     0.7559    0.8702    0.8090     42575
#
#     accuracy                         0.7628    127725
#    macro avg     0.7642    0.7628    0.7575    127725
# weighted avg     0.7642    0.7628    0.7575    127725
#
# GridSearch Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6437    0.8107    0.7176      5874
#            1     0.8551    0.5823    0.6928     10599
#            2     0.5420    0.8273    0.6549      3527
#
#     accuracy                         0.6926     20000
#    macro avg     0.6802    0.7401    0.6884     20000
# weighted avg     0.7378    0.6926    0.6934     20000

# %% [markdown]
# ## 2) Optuna

# %%
best_f1_score = 0
best_params = {}

def objective(trial):
    global best_f1_score, best_params
    
    n_estimators = trial.suggest_int('n_estimators', 50, 500, step=50)
    max_depth = trial.suggest_int('max_depth', 3, 15, step=3)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
    
    rf = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42,
        n_jobs=-1
    )

    rf.fit(X_train, y_train)
    
    y_val_pred = rf.predict(X_test)
    f1 = f1_score(y_test, y_val_pred, average='macro')
    
    return f1

# %%
study = optuna.create_study(
    direction='maximize',
    sampler=TPESampler(seed=42)
)

study.optimize(objective, n_trials=30, show_progress_bar=True)
# Out:
# [I 2025-08-22 08:21:25,082] A new study created in memory with name: no-name-8191267d-8994-4ca9-b5cc-113f19c19540
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-08-22 08:21:53,058] Trial 0 finished with value: 0.7256832241732054 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:22:44,261] Trial 1 finished with value: 0.6934006328910756 and parameters: {'n_estimators': 450, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:23:03,731] Trial 2 finished with value: 0.6620218064858948 and parameters: {'n_estimators': 100, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:23:10,503] Trial 3 finished with value: 0.6660884741990993 and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:24:08,531] Trial 4 finished with value: 0.6620218064858948 and parameters: {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:26:52,644] Trial 5 finished with value: 0.6760838644890436 and parameters: {'n_estimators': 450, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 0 with value: 0.7256832241732054.
# [I 2025-08-22 08:27:31,720] Trial 6 finished with value: 0.7660929340237025 and parameters: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 6 with value: 0.7660929340237025.
# [I 2025-08-22 08:28:48,726] Trial 7 finished with value: 0.76641375155152 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:28:58,619] Trial 8 finished with value: 0.6625911647317002 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:30:12,242] Trial 9 finished with value: 0.6758534599112777 and parameters: {'n_estimators': 200, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:30:46,575] Trial 10 finished with value: 0.6929063525702089 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:30:53,458] Trial 11 finished with value: 0.7229131509682517 and parameters: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:33:05,339] Trial 12 finished with value: 0.7345819558903477 and parameters: {'n_estimators': 200, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 7 with value: 0.76641375155152.
# [I 2025-08-22 08:35:02,566] Trial 13 finished with value: 0.767444851215731 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:36:21,713] Trial 14 finished with value: 0.6986292681087124 and parameters: {'n_estimators': 150, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:36:50,559] Trial 15 finished with value: 0.6933365987053627 and parameters: {'n_estimators': 250, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:38:47,187] Trial 16 finished with value: 0.7652246436445299 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:41:49,574] Trial 17 finished with value: 0.698333274697037 and parameters: {'n_estimators': 350, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:42:09,677] Trial 18 finished with value: 0.7300897107778983 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:42:21,102] Trial 19 finished with value: 0.6938011900998707 and parameters: {'n_estimators': 100, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:45:23,907] Trial 20 finished with value: 0.6985147023404935 and parameters: {'n_estimators': 350, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:46:03,452] Trial 21 finished with value: 0.7660929340237025 and parameters: {'n_estimators': 50, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 13 with value: 0.767444851215731.
# [I 2025-08-22 08:47:21,197] Trial 22 finished with value: 0.7690988320396767 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 22 with value: 0.7690988320396767.
# [I 2025-08-22 08:48:38,664] Trial 23 finished with value: 0.76641375155152 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 22 with value: 0.7690988320396767.
# [I 2025-08-22 08:50:17,779] Trial 24 finished with value: 0.7347241109099262 and parameters: {'n_estimators': 150, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 22 with value: 0.7690988320396767.
# [I 2025-08-22 08:53:30,265] Trial 25 finished with value: 0.7658108361343973 and parameters: {'n_estimators': 250, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': None}. Best is trial 22 with value: 0.7690988320396767.
# [I 2025-08-22 08:55:41,572] Trial 26 finished with value: 0.7345819558903477 and parameters: {'n_estimators': 200, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': None}. Best is trial 22 with value: 0.7690988320396767.
# [I 2025-08-22 08:56:58,864] Trial 27 finished with value: 0.7696986842495145 and parameters: {'n_estimators': 100, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 27 with value: 0.7696986842495145.
# [I 2025-08-22 08:57:55,615] Trial 28 finished with value: 0.6955291162256086 and parameters: {'n_estimators': 500, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 27 with value: 0.7696986842495145.
# [I 2025-08-22 08:58:22,483] Trial 29 finished with value: 0.7285956501355338 and parameters: {'n_estimators': 200, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 27 with value: 0.7696986842495145.

# %%
print(f"\nBest Optuna F1-macro: {study.best_value:.4f}")
print(f"Best Optuna parameters:")
for param, value in study.best_params.items():
    print(f"  {param}: {value}")
# Out:
# Best Optuna F1-macro: 0.7697
# Best Optuna parameters:
#   n_estimators: 100
#   max_depth: 15
#   min_samples_split: 7
#   min_samples_leaf: 3
#   max_features: None

# %%
rf_optuna = RandomForestClassifier(
    **study.best_params,
    random_state=42,
    n_jobs=-1
)

rf_optuna.fit(X_train, y_train)

y_train_pred_optuna = rf_optuna.predict(X_train)
y_test_pred_optuna = rf_optuna.predict(X_test)

optuna_train_f1 = f1_score(y_train, y_train_pred_optuna, average='macro')
optuna_test_f1 = f1_score(y_test, y_test_pred_optuna, average='macro')
optuna_train_acc = accuracy_score(y_train, y_train_pred_optuna)
optuna_test_acc = accuracy_score(y_test, y_test_pred_optuna)

print(f"\nOptuna Train F1-macro: {optuna_train_f1:.4f}, Train Accuracy: {optuna_train_acc:.4f}")
print(f"Optuna Test F1-macro: {optuna_test_f1:.4f}, Test Accuracy: {optuna_test_acc:.4f}")

print("\nOptuna Train Classification Report:")
print(classification_report(y_train, y_train_pred_optuna, digits=4))

print("Optuna Test Classification Report:")
print(classification_report(y_test, y_test_pred_optuna, digits=4))
# Out:
# Optuna Train F1-macro: 0.8581, Train Accuracy: 0.8595
# Optuna Test F1-macro: 0.7697, Test Accuracy: 0.7774
#
# Optuna Train Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8702    0.8993    0.8845     42575
#            1     0.8515    0.7630    0.8048     42575
#            2     0.8559    0.9163    0.8850     42575
#
#     accuracy                         0.8595    127725
#    macro avg     0.8592    0.8595    0.8581    127725
# weighted avg     0.8592    0.8595    0.8581    127725
#
# Optuna Test Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7547    0.8408    0.7955      5874
#            1     0.8613    0.7242    0.7868     10599
#            2     0.6455    0.8316    0.7268      3527
#
#     accuracy                         0.7774     20000
#    macro avg     0.7538    0.7989    0.7697     20000
# weighted avg     0.7919    0.7774    0.7788     20000

# %% [markdown]
# # Model Saving

# %%
import joblib

model_filename = 'rf_optuna_model.joblib'
joblib.dump(rf_optuna, model_filename)
# Out:
# ['rf_optuna_model.joblib']

# %% [markdown]
# Save model RF optuna because of better result in both supressing overfitting & F1-Macro test
